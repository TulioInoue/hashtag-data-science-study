# %% [markdown]
# # Testes de hipóteses

# %% [markdown]
# Uma **hipótese estatística** é uma suposição sobre determinado parâmetro da população, como média, desvio-padrão, coeficiente de correlação, etc. Um teste de hipótese é um procedimento para decisão sobre a veracidade ou falsidade de determinada hipótese dentro de um limite. Para uma hipótese estatística ser validada ou rejeitada com certeza, seria necessário examinarmos toda a população, o que, na prática, é inviável. Como alternativa, extraímos uma amostra aleatória da população de interesse. Como a decisão é tomada com base na amostra, podem ocorrer erros (rejeitar uma hipótese quando ela for verdadeira ou não rejeitar uma hipótese quando ela for falsa), como será visto mais adiante.
#
# O procedimento e os conceitos necessários para a construção de um teste de hipótese serão apresentados a seguir. Vamos considerar $X$ uma variável associada a uma população e $\theta$ determinado parâmetro dessa população. Devemos definir a hipótese a ser testada sobre o parâmetro $\theta$ dessa população, que é chamada de *hipótese nula*:
#
# $$
# H_0: \theta = \theta_0
# $$
#
# Definiremos também a hipótese alternativa ($H_1$), caso $H_0$ seja rejeitada, que pode ser caracterizada da seguinte forma:
#
# $$
# H_1: \theta \neq \theta_0
# $$
#
# e o teste é chamado de **teste bilateral (ou bicaudal)**.
